# %%
def OddEven():
    num=int(input("Enter the number:"))
    if(num%2==0):
        print(num,("is Even number"))
        message=("is Even number")
    else:
        print(num,("is Odd number"))
        message=(num,("is Odd number"))
        return  message

# %%
 OddEven()
# Out:
# Enter the number: 52452
# 52452 is Even number

# %%
def eligibility():
    gender=str(input("Your gender:"))
    age=int(input("Your age:"))
    if((gender=="male")or(gender=="female")("male">=21) or("female">=18)):
       print("NOT ELIGIBLE")
       rule="NOT ELIGIBLE" 
    else:
       print("ELIGIBLE") 
       rule="ELIGIBLE"
    return rule

# %%
rule=eligibility()
# Out:
# Your gender: male
# Your age: 20
# NOT ELIGIBLE

# %%
def percentage():
    subject1=int(input("subject 1:"))
    subject2=int(input("subject 2:"))
    subject3=int(input("subject 3:"))
    subject4=int(input("subject 4:"))
    subject5=int(input("subject 5:"))
    marksobtained=subject1+subject2+subject3+subject4+subject5
    print("Total:",marksobtained)
    value="Total"
    percentage=(marksobtained/500)*100
    print("Percentage:",percentage)
    value="Percentage"
    return value

# %%
value=percentage()
# Out:
# subject 1: 98
# subject 2: 87
# subject 3: 95
# subject 4: 95
# subject 5: 93
# Total: 468
# Percentage: 93.60000000000001

# %%
def triangle():
    height=int(input("Height:"))
    breadth=int(input("Breadth:"))
    formula1=(height*breadth/2)            
    print( "Area of triangle:",formula1)
    angle= "Area of triangle:"
    height1=int(input("Height 1:"))
    height2=int(input("Height 2:"))
    breadth=int(input("Breadth:"))
    formula2=(height1+height2+breadth)
    print("Perimeter of Triangle:",formula2)
    angle="Perimeter of Triangle:"
    return angle

# %%
angle=triangle()
# Out:
# Height: 32
# Breadth: 34
# Area of triangle: 544.0
# Height 1: 2
# Height 2: 4
# Breadth: 4
# Perimeter of Triangle: 10
